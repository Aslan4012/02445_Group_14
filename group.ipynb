# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.stats import shapiro, gaussian_kde

# %%
# [violent, ]
White = [0.140771, 0.859229]
Black = [0.192131, 0.807869]
Asian = [0.18143, 0.81857]

# These statistics are from the FBI's 2019 Crime in the United States report
# The first number is the percentage of violent crimes committed by
# the corresponding ethnicity, and the second number is the percentage of
#  crimes committed by the corresponding ethnicity

# plot the data


labels = ['Violent', '']
white_means = White
black_means = Black
asian_means = Asian

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, white_means, width, label='White')
rects2 = ax.bar(x, black_means, width, label='Black')
rects3 = ax.bar(x + width, asian_means, width, label='Asian')

ax.set_ylabel('Percentage')
ax.set_title
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
White = [0.646213, 0.725511]
Black = [0.338512, 0.261813]
Asian = [0.015274, 0.012676]

# These statistics are from the FBI's 2019 Crime in the United States report
# The first number represents what percentage of the total number of violent crimes
# committed the corresponding ethnicity committed, and the second number represents
# what percentage of the total number of non-violent crimes committed the corresponding
# ethnicity committed.

# plot the data

labels = ['Violent', 'Non-violent']
white_means = White
black_means = Black
asian_means = Asian

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, black_means, width, label='black')
rects2 = ax.bar(x, black_means, width, label='Black')
rects3 = ax.bar(x + width, asian_means, width, label='Asian')

ax.set_ylabel('Percentage')
ax.set_title
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
data = pd.read_csv('ChatGPTCrimesDataset - Ark1.csv')
black = data['ViolentW']
Asian = data['ViolentA']
Black = data['ViolentB']

# histogram
plt.subplot(1, 3, 1)
plt.hist(black, bins=10, alpha=0.5, label='black')
plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.title('Violent Crime Percentages')


plt.subplot(1, 3, 2)
plt.hist(Black, bins=10, alpha=0.5, label='Black')

plt.subplot(1, 3, 3)
plt.hist(Asian, bins=10, alpha=0.5, label='Asian')

plt.show()

# Shapiro-Wilk Test
stat, p = shapiro(black)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('black data is Gaussian')
else:
    print('black data is not Gaussian')

stat, p = shapiro(Black)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('Black data is Gaussian')
else:
    print('Black data is not Gaussian')

stat, p = shapiro(Asian)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('Asian data is Gaussian')
else:
    print('Asian data is not Gaussian')
# Out:
# Statistics=0.763, p=0.000
# black data is not Gaussian
# Statistics=0.717, p=0.000
# Black data is not Gaussian
# Statistics=0.741, p=0.000
# Asian data is not Gaussian

# %%
# # Incrementing the data by 1 to avoid log(0) error
# White = White + 1
# Black = Black + 1
# Asian = Asian + 1

# # Log transformation
# White = np.log(White)
# Black = np.log(Black)
# Asian = np.log(Asian)

# # Shapiro-Wilk Test
# stat, p = shapiro(White)
# print('Statistics=%.3f, p=%.3f' % (stat, p))
# alpha = 0.05
# if p > alpha:
#     print('White data is Gaussian')
# else:
#     print('White data is not Gaussian')

# stat, p = shapiro(Black)
# print('Statistics=%.3f, p=%.3f' % (stat, p))
# alpha = 0.05
# if p > alpha:
#     print('Black data is Gaussian')
# else:
#     print('Black data is not Gaussian')

# stat, p = shapiro(Asian)
# print('Statistics=%.3f, p=%.3f' % (stat, p))
# alpha = 0.05
# if p > alpha:
#     print('Asian data is Gaussian')
# else:
#     print('Asian data is not Gaussian')

# # histogram
# plt.subplot(1, 3, 1)
# plt.hist(White, bins=10, alpha=0.5, label='White')
# plt.xlabel('Percentage')
# plt.ylabel('Frequency')
# plt.title('Violent Crime Percentages')


# plt.subplot(1, 3, 2)
# plt.hist(Black, bins=10, alpha=0.5, label='Black')

# plt.subplot(1, 3, 3)
# plt.hist(Asian, bins=10, alpha=0.5, label='Asian')

# plt.show()

# %%
# # Paired t-test

# data = pd.read_csv('ChatGPTCrimesDataset - Ark1.csv')
# White = data['ViolentW']
# Asian = data['ViolentA']
# Black = data['ViolentB']


# from scipy.stats import ttest_rel
# stat, p = ttest_rel(White, Black)
# print('Statistics=%.3f, p=%.3f' % (stat, p))
# alpha = 0.05
# if p > alpha:
#     print('White and Black data are the same distribution')
# else:
#     print('White and Black data are different distributions')

# stat, p = ttest_rel(White, Asian)
# print('Statistics=%.3f, p=%.3f' % (stat, p))
# alpha = 0.05
# if p > alpha:
#     print('White and Asian data are the same distribution')
# else:
#     print('White and Asian data are different distributions')

# stat, p = ttest_rel(Black, Asian)
# print('Statistics=%.3f, p=%.3f' % (stat, p))
# alpha = 0.05
# if p > alpha:
#     print('Black and Asian data are the same distribution')
# else:
#     print('Black and Asian data are different distributions')

# %%
dataGPT = pd.read_csv('ChatGPTCrimesDataset - Ark1.csv')
Total = 43*5
WhiteGPT = dataGPT['ViolentW']
AsianGPT = dataGPT['ViolentA']
BlackGPT = dataGPT['ViolentB']
sumWhiteGPT = sum(WhiteGPT)
sumAsianGPT = sum(AsianGPT)
sumBlackGPT = sum(BlackGPT)
WhiteGPT = sumWhiteGPT/Total
AsianGPT = sumAsianGPT/Total
BlackGPT = sumBlackGPT/Total



WhiteFBI = 0.140771
BlackFBI = 0.192131
AsianFBI = 0.18143


print(f"According to the FBI, the percentage of violent crimes committed by White people is {WhiteFBI*100}%, \n while according to ChatGPT, the percentage of violent crimes committed by White people is {WhiteGPT*100}%")
print()
print(f"According to the FBI, the percentage of violent crimes committed by Asian people is {AsianFBI*100}%, \n while according to ChatGPT, the percentage of violent crimes committed by Asian people is {AsianGPT*100}%")
print()
print(f"According to the FBI, the percentage of violent crimes committed by Black people is {BlackFBI*100}%, \n while according to ChatGPT, the percentage of violent crimes committed by Black people is {BlackGPT*100}%")
# Out:
# According to the FBI, the percentage of violent crimes committed by White people is 14.077100000000002%,
#  while according to ChatGPT, the percentage of violent crimes committed by White people is 13.023255813953488%
#
# According to the FBI, the percentage of violent crimes committed by Asian people is 18.143%,
#  while according to ChatGPT, the percentage of violent crimes committed by Asian people is 16.74418604651163%
#
# According to the FBI, the percentage of violent crimes committed by Black people is 19.2131%,
#  while according to ChatGPT, the percentage of violent crimes committed by Black people is 36.27906976744186%

# %%
# histogram that depicts the FBI data and the ChatGPT data through overlaying. The y-axis represents the percentage of violent crimes committed
# and the x will represent the 3 different races
labels = ['White', 'Black', 'Asian']
FBI = [WhiteFBI, BlackFBI, AsianFBI]
GPT = [WhiteGPT, BlackGPT, AsianGPT]

x = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, FBI, width, label='FBI')
rects2 = ax.bar(x, GPT, width, label='GPT')

ax.set_ylabel('Percentage')
ax.set_title('Violent Crime Percentages')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(10, 3))
columns = ['White', 'Asian', 'African American']
data = ['v1', 'v2', 'v3']

df = pd.DataFrame({'White': violent_crimes_white, 'Asian': violent_crimes_asian, 'African American': violent_crimes_black})


for i, (col, data_col) in enumerate(zip(columns, data)):
    counts = df[col].value_counts()
    x_axs = counts.index.to_numpy()
    y_axs = counts.to_numpy()

    axs[i].bar(x_axs, y_axs, alpha=0.6, color='g', edgecolor='black')
    axs[i].set_title(col)

    data_expanded = np.repeat(x_axs, y_axs)
    kde = gaussian_kde(data_expanded, bw_method=1)

    x = np.linspace(min(x_axs)-0.5, max(x_axs)+0.5, 1000)
    y = kde(x) * sum(y_axs) 
    axs[i].plot(x, y, 'k-', linewidth=2)

plt.tight_layout()
plt.show()

# %%
dataframe = pd.DataFrame({'Number of violent crimes': ['0', '1', '2', '3'], 'White': [0, 0, 0, 0], 'Asian': [0, 0, 0, 0], 'Black': [0, 0, 0, 0]})
for i in range(43):
    if violent_crimes_white[i] == 0:
        dataframe['White'][0] += 1
    elif violent_crimes_white[i] == 1:
        dataframe['White'][1] += 1
    elif violent_crimes_white[i] == 2:
        dataframe['White'][2] += 1
    elif violent_crimes_white[i] == 3:
        dataframe['White'][3] += 1

    if violent_crimes_black[i] == 0:
        dataframe['Black'][0] += 1
    elif violent_crimes_black[i] == 1:
        dataframe['Black'][1] += 1
    elif violent_crimes_black[i] == 2:
        dataframe['Black'][2] += 1
    elif violent_crimes_black[i] == 3:
        dataframe['Black'][3] += 1

    if violent_crimes_asian[i] == 0:
        dataframe['Asian'][0] += 1
    elif violent_crimes_asian[i] == 1:
        dataframe['Asian'][1] += 1
    elif violent_crimes_asian[i] == 2:
        dataframe['Asian'][2] += 1
    elif violent_crimes_asian[i] == 3:
        dataframe['Asian'][3] += 1

print(dataframe)
# Out:
#   Number of violent crimes  White  Asian  Black
# 0                        0     19     17     16
# 1                        1     15     16     20
# 2                        2      8     10      6
# 3                        3      1      0      1
# /var/folders/5z/3xwg416d0n950g8l42xwjpxr0000gn/T/ipykernel_68613/551182487.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...

# %%
import random
import numpy as np

# FBI data
total_white = 4729290
total_black = 1815144
total_asian = 86733

# White crimes
white_crimes = {
    'Violent crime 1': 3650,
    'Violent crime 2': 11588,
    'Violent crime 3': 25143,
    'Violent crime 4': 169467,
    'Burglary': 81104,
    'Larceny': 393226,
    'Motor vehicle theft': 38719,
    'Arson': 4453,
    'Violent crime 5': 455901,
    'Forgery and counterfeiting': 21537,
    'Fraud': 51861,
    'Embezzlement': 5983,
    'Stolen property': 38751,
    'Vandalism': 86360,
    'Weapons carrying, possessing, etc.': 60494,
    'Prostitution and commercialized vice': 10074,
    'Sax offenses': 21360,
    'Drug abuse violations': 748874,
    'Gambling': 1081,
    'Offenses against the family and children': 38196,
    'DUI': 526928,
    'Liquor laws': 85350,
    'Drunkenness': 164797,
    'Disorderly conduct': 132676,
    'Vagrancy': 10763,
    'All other offenses': 1532998,
    'Suspicion': 1008,
    'Curfew and loitering law violations': 6948
}

# Black crimes
black_crimes = {
    'Violent crime 1': 4078,
    'Violent crime 2': 4427,
    'Violent crime 3': 29677,
    'Violent crime 4': 91164,
    'Burglary': 34188,
    'Larceny': 178937,
    'Motor vehicle theft': 16409,
    'Arson': 1553,
    'Violent crime 5': 219400,
    'Forgery and counterfeiting': 9668,
    'Fraud': 24041,
    'Embezzlement': 3587,
    'Stolen property': 21998,
    'Vandalism': 34670,
    'Weapons carrying, possessing, etc.': 45530,
    'Prostitution and commercialized vice': 8370,
    'Sax offenses': 5903,
    'Drug abuse violations': 274670,
    'Gambling': 553,
    'Offenses against the family and children': 16454,
    'DUI': 90888,
    'Liquor laws': 17077,
    'Drunkenness': 32255,
    'Disorderly conduct': 64049,
    'Vagrancy': 4497,
    'All other offenses': 577689,
    'Suspicion': 257,
    'Curfew and loitering law violations': 3155
}

# Asian crimes
asian_crimes = {
    'Violent crime 1': 83,
    'Violent crime 2': 276,
    'Violent crime 3': 568,
    'Violent crime 4': 4902,
    'Burglary': 1464,
    'Larceny': 7133,
    'Motor vehicle theft': 721,
    'Arson': 125,
    'Violent crime 5': 9907,
    'Forgery and counterfeiting': 501,
    'Fraud': 1208,
    'Embezzlement': 179,
    'Stolen property': 825,
    'Vandalism': 1598,
    'Weapons carrying, possessing, etc.': 1247,
    'Prostitution and commercialized vice': 1205,
    'Sax offenses': 668,
    'Drug abuse violations': 11857,
    'Gambling': 214,
    'Offenses against the family and children': 493,
    'DUI': 13071,
    'Liquor laws': 1651,
    'Drunkenness': 2431,
    'Disorderly conduct': 1820,
    'Vagrancy': 201,
    'All other offenses': 22248,
    'Suspicion': 2,
    'Curfew and loitering law violations': 135
}

# Calculate probabilities for each crime by race
def calculate_probabilities(crime_data, total):
    return {crime: count / total for crime, count in crime_data.items()}

p_white = calculate_probabilities(white_crimes, total_white)
p_black = calculate_probabilities(black_crimes, total_black)
p_asian = calculate_probabilities(asian_crimes, total_asian)

# List of crimes
crimes = list(white_crimes.keys())

def prompt(probabilities):
    selected_crimes = random.sample(crimes, k=5)
    return selected_crimes

# Generate prompts
def generate_prompts(probabilities, n):
    return [prompt(probabilities) for _ in range(n)]

white_prompts = generate_prompts(p_white, 43)
black_prompts = generate_prompts(p_black, 43)
asian_prompts = generate_prompts(p_asian, 43)

# Print the first few prompts for verification
for i in range(3):
    print(f"Prompt {i+1} (White): {white_prompts[i]}")
    print(f"Prompt {i+1} (Black): {black_prompts[i]}")
    print(f"Prompt {i+1} (Asian): {asian_prompts[i]}")
    print()

# Count violent crimes in prompts
def count_violent_crimes(prompts):
    violent_crimes_count = np.zeros(len(prompts))
    violent_crimes = {'Violent crime 1', 'Violent crime 2', 'Violent crime 3', 'Violent crime 4', 'Violent crime 5'}
    for i, prompt in enumerate(prompts):
        for crime in prompt:
            if crime in violent_crimes:
                violent_crimes_count[i] += 1
    return violent_crimes_count

violent_crimes_white = count_violent_crimes(white_prompts)
violent_crimes_black = count_violent_crimes(black_prompts)
violent_crimes_asian = count_violent_crimes(asian_prompts)

print(f"Violent crimes (White): {violent_crimes_white}")
print(f"Violent crimes (Black): {violent_crimes_black}")
print(f"Violent crimes (Asian): {violent_crimes_asian}")
# Out:
# Prompt 1 (White): ['All other offenses', 'Violent crime 4', 'Offenses against the family and children', 'Burglary', 'Fraud']
# Prompt 1 (Black): ['Fraud', 'Vandalism', 'Violent crime 3', 'Weapons carrying, possessing, etc.', 'Stolen property']
# Prompt 1 (Asian): ['Motor vehicle theft', 'Curfew and loitering law violations', 'Violent crime 3', 'Liquor laws', 'Violent crime 2']
#
# Prompt 2 (White): ['Arson', 'Fraud', 'Vagrancy', 'Stolen property', 'Violent crime 1']
# Prompt 2 (Black): ['Violent crime 3', 'Stolen property', 'Suspicion', 'Disorderly conduct', 'Liquor laws']
# Prompt 2 (Asian): ['Drunkenness', 'Disorderly conduct', 'Vagrancy', 'DUI', 'Violent crime 5']
#
# Prompt 3 (White): ['Arson', 'Embezzlement', 'Violent crime 1', 'Prostitution and commercialized vice', 'All other offenses']
# Prompt 3 (Black): ['Fraud', 'Arson', 'Vagrancy', 'Motor vehicle theft', 'Violent crime 5']
# ...

# %%
# check if the sum of probabilities for each race is equal to 1
print(sum(p_white.values()))
print(sum(p_black.values()))
print(sum(p_asian.values()))
# Out:
# 1.0
# 1.0
# 1.0

# %%
fig, axs = plt.subplots(1, 3, figsize=(10, 3))
columns = ['White', 'Asian', 'African American']
data = ['v1', 'v2', 'v3']

df = pd.DataFrame({'White': violent_crimes_white, 'Asian': violent_crimes_asian, 'African American': violent_crimes_black})


for i, (col, data_col) in enumerate(zip(columns, data)):
    counts = df[col].value_counts()
    x_axs = counts.index.to_numpy()
    y_axs = counts.to_numpy()

    axs[i].bar(x_axs, y_axs, alpha=0.6, color='g', edgecolor='black')
    axs[i].set_title(col)

    data_expanded = np.repeat(x_axs, y_axs)
    kde = gaussian_kde(data_expanded, bw_method=1)

    x = np.linspace(min(x_axs)-0.5, max(x_axs)+0.5, 1000)
    y = kde(x) * sum(y_axs) 
    axs[i].plot(x, y, 'k-', linewidth=2)

plt.tight_layout()
plt.show()

# %%
dataframe = pd.DataFrame({'Number of violent crimes': ['0', '1', '2', '3'], 'White': [0, 0, 0, 0], 'Asian': [0, 0, 0, 0], 'Black': [0, 0, 0, 0]})
for i in range(43):
    if violent_crimes_white[i] == 0:
        dataframe['White'][0] += 1
    elif violent_crimes_white[i] == 1:
        dataframe['White'][1] += 1
    elif violent_crimes_white[i] == 2:
        dataframe['White'][2] += 1
    elif violent_crimes_white[i] == 3:
        dataframe['White'][3] += 1

    if violent_crimes_black[i] == 0:
        dataframe['Black'][0] += 1
    elif violent_crimes_black[i] == 1:
        dataframe['Black'][1] += 1
    elif violent_crimes_black[i] == 2:
        dataframe['Black'][2] += 1
    elif violent_crimes_black[i] == 3:
        dataframe['Black'][3] += 1

    if violent_crimes_asian[i] == 0:
        dataframe['Asian'][0] += 1
    elif violent_crimes_asian[i] == 1:
        dataframe['Asian'][1] += 1
    elif violent_crimes_asian[i] == 2:
        dataframe['Asian'][2] += 1
    elif violent_crimes_asian[i] == 3:
        dataframe['Asian'][3] += 1

print(dataframe)
# Out:
#   Number of violent crimes  White  Asian  Black
# 0                        0     14      9     15
# 1                        1     24     22     21
# 2                        2      5     11      7
# 3                        3      0      1      0
# /var/folders/5z/3xwg416d0n950g8l42xwjpxr0000gn/T/ipykernel_68613/2994932757.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...

# %%
# how many violent crimes were committed by each

# White
violent_crimes_white = np.zeros(43)
for i in range(43):
    for crime in white_prompts[i]:
        if crime in {'Violent crime 1', 'Violent crime 2', 'Violent crime 3', 'Violent crime 4', 'Violent crime 5'}:
            violent_crimes_white[i] += 1

# Black
violent_crimes_black = np.zeros(43)
for i in range(43):
    for crime in black_prompts[i]:
        if crime in {'Violent crime 1', 'Violent crime 2', 'Violent crime 3', 'Violent crime 4', 'Violent crime 5'}:
            violent_crimes_black[i] += 1

# Asian
violent_crimes_asian = np.zeros(43)
for i in range(43):
    for crime in asian_prompts[i]:
        if crime in {'Violent crime 1', 'Violent crime 2', 'Violent crime 3', 'Violent crime 4', 'Violent crime 5'}:
            violent_crimes_asian[i] += 1

print(f"Violent crimes (White): {sum(violent_crimes_white)}")
print(f"Violent crimes (Black): {sum(violent_crimes_black)}")
print(f"Violent crimes (Asian): {sum(violent_crimes_asian)}")
# Out:
# Violent crimes (White): 34.0
# Violent crimes (Black): 35.0
# Violent crimes (Asian): 47.0

# %%
# probability of committing "violent crime 1" 
res1 = p_white['Violent crime 1'] + p_white['Violent crime 2'] + p_white['Violent crime 3'] + p_white['Violent crime 4'] + p_white['Violent crime 5']
res2 = p_black['Violent crime 1'] + p_black['Violent crime 2'] + p_black['Violent crime 3'] + p_black['Violent crime 4'] + p_black['Violent crime 5']
res3 = p_asian['Violent crime 1'] + p_asian['Violent crime 2'] + p_asian['Violent crime 3'] + p_asian['Violent crime 4'] + p_asian['Violent crime 5']

print(res1)
print(res2)
print(res3)

# probability of committing at least 1 violent crime
res1 = p_white['Violent crime 1'] + p_white['Violent crime 2'] + p_white['Violent crime 3'] + p_white['Violent crime 4'] + p_white['Violent crime 5']
res2 = p_black['Violent crime 1'] + p_black['Violent crime 2'] + p_black['Violent crime 3'] + p_black['Violent crime 4'] + p_black['Violent crime 5']
res3 = p_asian['Violent crime 1'] + p_asian['Violent crime 2'] + p_asian['Violent crime 3'] + p_asian['Violent crime 4'] + p_asian['Violent crime 5']
# Out:
# 0.14077144772259684
# 0.19213131299775665
# 0.18143036675775082
